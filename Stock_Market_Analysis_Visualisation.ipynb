# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import xticks
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# read data Bajaj1 :
df = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Bajaj1.csv')
df.head()
# Out:
#          Date  Close Price    20 Day MA    50 Day MA
# 0  2015-01-01      2454.10  2454.100000  2454.100000
# 1  2015-01-02      2453.50  2453.800000  2453.800000
# 2  2015-01-05      2460.15  2455.916667  2455.916667
# 3  2015-01-06      2440.35  2452.025000  2452.025000
# 4  2015-01-07      2447.20  2451.060000  2451.060000

# %%
# read data Eicher1 :
df1 = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Eicher1.csv')
df1.head()
# Out:
#          Date  Close Price     20 Day MA     50 Day MA
# 0  2015-01-01     15239.15  15239.150000  15239.150000
# 1  2015-01-02     15065.55  15152.350000  15152.350000
# 2  2015-01-05     15133.55  15146.083333  15146.083333
# 3  2015-01-06     14753.10  15047.837500  15047.837500
# 4  2015-01-07     14945.55  15027.380000  15027.380000

# %%
# read data Hero1 :
df2 = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Hero1.csv')
df2.head()
# Out:
#          Date  Close Price  20 Day MA  50 Day MA
# 0  2015-01-01      3107.30   3107.300   3107.300
# 1  2015-01-02      3097.75   3102.525   3102.525
# 2  2015-01-05      3118.65   3107.900   3107.900
# 3  2015-01-06      3011.80   3083.875   3083.875
# 4  2015-01-07      2977.10   3062.520   3062.520

# %%
# read data Infosys1 :
df3 = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Infosys1.csv')
df3.head()
# Out:
#          Date  Close Price    20 Day MA    50 Day MA
# 0  2015-01-01      1975.80  1975.800000  1975.800000
# 1  2015-01-02      2013.45  1994.625000  1994.625000
# 2  2015-01-05      1996.60  1995.283333  1995.283333
# 3  2015-01-06      1956.85  1985.675000  1985.675000
# 4  2015-01-07      1964.80  1981.500000  1981.500000

# %%
# read data Tcs1 :
df4 = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Tcs1.csv')
df4.head()
# Out:
#          Date  Close Price    20 Day MA    50 Day MA
# 0  2015-01-01      2548.20  2548.200000  2548.200000
# 1  2015-01-02      2570.85  2559.525000  2559.525000
# 2  2015-01-05      2537.90  2552.316667  2552.316667
# 3  2015-01-06      2446.55  2525.875000  2525.875000
# 4  2015-01-07      2416.80  2504.060000  2504.060000

# %%
# read data Tvs1 :
df5 = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Tvs1.csv')
df5.head()
# Out:
#          Date  Close Price  20 Day MA  50 Day MA
# 0  2015-01-01       276.85   276.8500   276.8500
# 1  2015-01-02       267.80   272.3250   272.3250
# 2  2015-01-05       271.20   271.9500   271.9500
# 3  2015-01-06       268.00   270.9625   270.9625
# 4  2015-01-07       278.55   272.4800   272.4800

# %%
df['Date'] = pd.to_datetime(df.Date)
df1['Date'] = pd.to_datetime(df1.Date)
df2['Date'] = pd.to_datetime(df2.Date)
df3['Date'] = pd.to_datetime(df3.Date)
df4['Date'] = pd.to_datetime(df4.Date)
df5['Date'] = pd.to_datetime(df5.Date)

# %%
df.head()
# Out:
#         Date  Close Price    20 Day MA    50 Day MA
# 0 2015-01-01      2454.10  2454.100000  2454.100000
# 1 2015-01-02      2453.50  2453.800000  2453.800000
# 2 2015-01-05      2460.15  2455.916667  2455.916667
# 3 2015-01-06      2440.35  2452.025000  2452.025000
# 4 2015-01-07      2447.20  2451.060000  2451.060000

# %%
# Bajaj Visualisation :
df.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
# Eicher Visualisation :
df1.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
# Hero Visualisation :
df2.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
# Infosys Visualisation :
df3.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
# Tcs Visualisation :
df4.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
# Tvs Visualisation :
df5.plot(x = 'Date', y = ['20 Day MA','50 Day MA'],figsize =(10,5))
plt.show()

# %%
df_diff = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Difference_Close_Price.csv')
df_diff
# Out:
#            STOCK  Min(Close Price)  Max(Close Price)  Difference
# 0          BAJAJ           1949.40            3409.5     1460.10
# 1  Eicher Motors          14320.60           32786.4    18465.80
# 2  Hero Motocorp           2279.80            4047.3     1767.50
# 3        Infosys            873.50            2326.6     1453.10
# 4            TCS           1721.20            3604.8     1883.60
# 5     Tvs Motors            213.55             785.3      571.75

# %%
df_diff.plot(x = 'STOCK', y = 'Difference',figsize =(10,5))
plt.show()

# %%
df_master = pd.read_csv('C:/Users/Soumadeep-Chitti/Desktop/DATA SCIENCE/COURSE4-Big Data & SQL/MySQL Assignment-Stock Market Analysis/Assignment/Master_Table.csv')
df_master.head()
# Out:
#          Date    Bajaj      TCS     TVS  Infosys    Eicher     Hero
# 0  2015-01-01  2454.10  2548.20  276.85  1975.80  15239.15  3107.30
# 1  2015-01-02  2453.50  2570.85  267.80  2013.45  15065.55  3097.75
# 2  2015-01-05  2460.15  2537.90  271.20  1996.60  15133.55  3118.65
# 3  2015-01-06  2440.35  2446.55  268.00  1956.85  14753.10  3011.80
# 4  2015-01-07  2447.20  2416.80  278.55  1964.80  14945.55  2977.10

# %%
df_master['Date'] = pd.to_datetime(df['Date'])
df_master['Year'] = df_master['Date'].dt.year

# %%
df_master.head()
# Out:
#         Date    Bajaj      TCS     TVS  Infosys    Eicher     Hero  Year
# 0 2015-01-01  2454.10  2548.20  276.85  1975.80  15239.15  3107.30  2015
# 1 2015-01-02  2453.50  2570.85  267.80  2013.45  15065.55  3097.75  2015
# 2 2015-01-05  2460.15  2537.90  271.20  1996.60  15133.55  3118.65  2015
# 3 2015-01-06  2440.35  2446.55  268.00  1956.85  14753.10  3011.80  2015
# 4 2015-01-07  2447.20  2416.80  278.55  1964.80  14945.55  2977.10  2015

# %%
df_master.drop(['Date'], axis = 1) 
df_master.head()
# Out:
#         Date    Bajaj      TCS     TVS  Infosys    Eicher     Hero  Year
# 0 2015-01-01  2454.10  2548.20  276.85  1975.80  15239.15  3107.30  2015
# 1 2015-01-02  2453.50  2570.85  267.80  2013.45  15065.55  3097.75  2015
# 2 2015-01-05  2460.15  2537.90  271.20  1996.60  15133.55  3118.65  2015
# 3 2015-01-06  2440.35  2446.55  268.00  1956.85  14753.10  3011.80  2015
# 4 2015-01-07  2447.20  2416.80  278.55  1964.80  14945.55  2977.10  2015

# %%
df_master = df_master.groupby('Year')

# %%
df_master.head()
# Out:
#           Date    Bajaj      TCS     TVS  Infosys    Eicher     Hero  Year
# 0   2015-01-01  2454.10  2548.20  276.85  1975.80  15239.15  3107.30  2015
# 1   2015-01-02  2453.50  2570.85  267.80  2013.45  15065.55  3097.75  2015
# 2   2015-01-05  2460.15  2537.90  271.20  1996.60  15133.55  3118.65  2015
# 3   2015-01-06  2440.35  2446.55  268.00  1956.85  14753.10  3011.80  2015
# 4   2015-01-07  2447.20  2416.80  278.55  1964.80  14945.55  2977.10  2015
# 248 2016-01-01  2520.05  2416.25  287.10  1103.15  17365.25  2687.85  2016
# 249 2016-01-04  2488.15  2375.50  286.45  1080.60  17506.25  2645.50  2016
# 250 2016-01-05  2497.05  2350.35  286.95  1074.80  17169.50  2621.05  2016
# 251 2016-01-06  2485.50  2381.20  286.55  1069.45  17550.15  2581.75  2016
# 252 2016-01-07  2419.25  2370.05  277.60  1051.25  17066.30  2513.15  2016
# 495 2017-01-02  2596.80  2359.05  366.15  1001.60  22510.60  3028.70  2017
# ...
